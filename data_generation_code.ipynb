# %%
 # pip install google-generativeai

# %%
# pip install faker

# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyDQv_M_9p4vr3juNfrxGHfE_ufzkDjFXNA")

# %%
# model = genai.GenerativeModel('gemini-pro')
model = genai.GenerativeModel('gemini-2.5-flash')
response = model.generate_content("Explain how AI works in 5 sentences")
result = response.text
print(response.text)
# Out:
# AI systems learn by analyzing vast amounts of data, such as images, text, or numbers. Through algorithms, they identify intricate patterns and relationships within this information. This learning process creates a "model," which is essentially a refined understanding of the data's underlying structure. When presented with new, unseen input, the AI applies this trained model to make predictions, classify information, or generate responses. Essentially, AI finds correlations in data and uses them to perform tasks or solve problems without explicit, step-by-step human programming for every scenario.

# %%
print(result)
# Out:
# AI learns from data to find patterns and make predictions.

# %%
import pandas as pd

# %%
data=pd.read_csv(r'https://raw.githubusercontent.com/junioralive/Indian-Medicine-Dataset/refs/heads/main/DATA/indian_medicine_data.csv')

# %%
data
# Out:
#             id                           name  price(₹)  Is_discontinued  \
# 0            1       Augmentin 625 Duo Tablet    223.42            False
# 1            2            Azithral 500 Tablet    132.36            False
# 2            3               Ascoril LS Syrup    118.00            False
# 3            4           Allegra 120mg Tablet    218.81            False
# 4            5                 Avil 25 Tablet     10.96            False
# ...        ...                            ...       ...              ...
# 253968  253969  Ziyapod 100mg Oral Suspension     62.30            False
# 253969  253970            Zemhart 30mg Tablet     54.00            False
# 253970  253971              Zivex 25mg Tablet     57.00            False
# 253971  253972        ZI Fast 500mg Injection    152.00            False
# 253972  253973      Zyvocol 1% Dusting Powder    110.00            False
#
#                             manufacturer_name       type  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'name', 'price(₹)', 'Is_discontinued', 'manufacturer_name',
#        'type', 'pack_size_label', 'short_composition1', 'short_composition2'],
#       dtype='object')

# %%
data['name'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0              Augmentin 625 Duo Tablet
# 1                   Azithral 500 Tablet
# 2                      Ascoril LS Syrup
# 3                  Allegra 120mg Tablet
# 4                        Avil 25 Tablet
#                       ...
# 253968    Ziyapod 100mg Oral Suspension
# 253969              Zemhart 30mg Tablet
# 253970                Zivex 25mg Tablet
# 253971          ZI Fast 500mg Injection
# 253972        Zyvocol 1% Dusting Powder
# Name: name, Length: 253973, dtype: object>

# %%
selected_data  = data[:100]
selected_data
# Out:
#      id                       name  price(₹)  Is_discontinued  \
# 0     1   Augmentin 625 Duo Tablet    223.42            False
# 1     2        Azithral 500 Tablet    132.36            False
# 2     3           Ascoril LS Syrup    118.00            False
# 3     4       Allegra 120mg Tablet    218.81            False
# 4     5             Avil 25 Tablet     10.96            False
# ..  ...                        ...       ...              ...
# 95   96             Amlip 5 Tablet     32.36            False
# 96   97  AntiD 300mcg/ml Injection   3039.42            False
# 97   98               Alerid Syrup     21.84            False
# 98   99        Aldactone 50 Tablet     70.60            False
# 99  100        Ampoxin 500 Capsule     88.90            False
#
#                        manufacturer_name       type         pack_size_label  \
# 0   Glaxo SmithKline Pharmaceuticals Ltd  allopathy     strip of 10 tablets
# ...

# %%
from faker import Faker 
import json        
from random import randint

# %%
concatid = str(selected_data['name'][0]).replace(" ","")[:4]
concatid
# Out:
# 'Augm'

# %%
from faker import Faker
import random
import pandas as pd

Faker.seed(0)
random.seed(0)
fake = Faker("en_US") 
fixed_digits = 6

idcode = []
for row in range(0,100):
    concatid = str(selected_data['name'][row]).replace(" ","")[:4]
    idcode.append(concatid + str(fake.unique.random_int(min=111111, max=999999)))


idcode
# Out:
# ['Augm996551',
#  'Azit515069',
#  'Asco905883',
#  'Alle552112',
#  'Avil153561',
#  'Alle382604',
#  'Amox647221',
#  'Azee620643',
#  'Atar535715',
#  'Asco932983',
#  'Acil981274',
#  'Alex429157',
#  'Anov610859',
#  'Augm486552',
#  'Ambr722831',
#  'Arka340164',
#  'Avom640313',
#  'Asth257150',
#  'Alle406639',
#  'Albe257645',
#  'Asth903629',
#  'Alpr210548',
#  'Altr759517',
#  'Ativ949345',
#  'Asco373785',
#  'Asth669544',
#  'Almo850537',
#  'Atar960685',
#  'Acil742251',
#  'Alda265211',
#  'Alle436324',
#  'Atar214671',
#  'Amlo876395',
#  'Axce188435',
#  'Ativ828320',
#  'Alka457347',
#  'Aldi606188',
#  'Alfo698118',
#  'Alpr216703',
#  'Arac482088',
#  'Anaf566373',
#  'Alex442667',
#  'Azit751672',
#  'ABPh782643',
#  'Alth325521',
#  'Augm690474',
#  'Azic611292',
#  'Aldi575308',
#  'Amox657789',
#  'Asth384256',
#  'Acem176415',
#  'Acec955243',
#  'Anob686463',
#  'Alex125834',
#  'Asth208913',
#  'Avil865776',
#  'Azee992010',
#  'Ator529307',
# ...

# %%
selected_data['idcode'] = idcode
selected_data
# Out:
# C:\Users\SUMIT\AppData\Local\Temp\ipykernel_7348\1011321910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['idcode'] = idcode
#      id                       name  price(₹)  Is_discontinued  \
# 0     1   Augmentin 625 Duo Tablet    223.42            False
# 1     2        Azithral 500 Tablet    132.36            False
# 2     3           Ascoril LS Syrup    118.00            False
# 3     4       Allegra 120mg Tablet    218.81            False
# 4     5             Avil 25 Tablet     10.96            False
# ..  ...                        ...       ...              ...
# 95   96             Amlip 5 Tablet     32.36            False
# 96   97  AntiD 300mcg/ml Injection   3039.42            False
# ...

# %%
# selected_data.to_csv('selected_data.csv')

# %%
from faker import Faker
import random
import pandas as pd

Faker.seed(0)
random.seed(0)
fake = Faker("en_US") 
fixed_digits = 6
concatid = 'ID'
idcode,name, city, country, job, age = [[] for k in range(0,6)] 
# idcode = []
for row in range(0,100):
    concatid = str(selected_data['name'][0]).replace(" ","")[:4]
    idcode.append(concatid + str(fake.unique.random_int(min=111111, max=999999)))
    name.append(fake.name())
    city.append(fake.city())
    country.append(fake.country())
    job.append(fake.job())
    age.append(random.randint(20,100))

d = {"ID Code":idcode, "Name":name, "Age":age, "City":city, "Country":country, "Job":job}
df = pd.DataFrame(d)
df.head()
# Out:
#     ID Code                   Name  Age                City  \
# 0  ID996551         Steve Williams   69        Sullivanport
# 1  ID722831         Colleen Taylor   73           Port Cody
# 2  ID669544  Dr. Stephanie Collins   25  Port Gabriellafort
# 3  ID482088            Levi Durham   53          Ramoshaven
# 4  ID955243           Sydney Davis   85            Pagetown
#
#                                         Country  \
# 0                                       Lesotho
# 1  South Georgia and the South Sandwich Islands
# 2                                        Monaco
# 3                                       Eritrea
# 4                                   New Zealand
#
#                                  Job
# 0                 Materials engineer
# 1             Fitness centre manager
# 2                       Chiropractor
# 3                Biomedical engineer
# 4  Research officer, political party
